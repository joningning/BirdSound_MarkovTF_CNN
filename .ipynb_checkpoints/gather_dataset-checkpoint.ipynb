# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np
from pathlib import Path
import sys
import os
import time
import warnings
# suppress all warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# import os
# import requests
#
# # Define parameters for the API request
# params = {
#     'query': 'species:Passer montanus',  # eurasian tree sparrow
#     'page': 1,  # Page number
#     'format': 'json'  # Response format
# }
#
# # Make the API request
# response = requests.get('https://www.xeno-canto.org/api/2/recordings', params=params)
#
# # if successful
# if response.status_code == 200:
#     data = response.json()
#     # Process the data, download audio files, etc.
#     for record in data['recordings']:
#         audio_url = record['file']
#         # Extract filename from the URL
#         filename = os.path.basename(audio_url)
#         # Specify the local file path where you want to save the audio file
#         local_filepath = os.path.join('C:\Users\Bojo\Desktop\python projects', filename)
#         # Download the audio file
#         with open(local_filepath, 'wb') as f:
#             audio_response = requests.get(audio_url)
#             f.write(audio_response.content)
#     print("Audio files downloaded successfully.")
# else:
#     print('Error:', response.status_code)

# %% [markdown]
# import requests
#
# # Define parameters for the API request
# params = {
#     'query': 'species:Passer montanus',  # eurasian tree sparrow
#     'page': 1,  # Page number
#     'format': 'json'  # Response format
# }
#
# # Make the API request
# response = requests.get('https://www.xeno-canto.org/api/2/recordings', params=params)
#
# # if successful
# if response.status_code == 200:
#     data = response.json()
#     # Process the data, download audio files, etc.
#     for record in data['recordings']:
#         audio_url = record['file']
#         # Extract filename from the URL
#         filename = os.path.basename(audio_url)
#         # Specify the local file path where you want to save the audio file
#         local_filepath = os.path.join('C:\Users\Bojo\Desktop\python projects', filename)
#         # Download the audio file
#         with open(local_filepath, 'wb') as f:
#             audio_response = requests.get(audio_url)
#             f.write(audio_response.content)
#     print("Audio files downloaded successfully.")
# else:
#     print('Error:', response.status_code)

# %%
from scipy import signal
import librosa
import librosa.display
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from maad import sound, util, rois
import urllib.parse

# %%
def grab_audio(path, audio_format='mp3'):
    filelist = []
    for root, dirs, files in os.walk(path, topdown=False):
        for name in files:
            if name[-3:].casefold() == audio_format and name[:2] != '._':
                filelist.append(os.path.join(root, name))
    return filelist

# %%
XC_ROOTDIR = './dataset/'

XC_DIR = 'data_sets'

data = [['Eurasian Tree Sparrow', 'Passer montanus'],
        ['Zebra Dove', 'Geopelia striata'],
        ['Golden-Bellied Flyeater', 'Gerygone sulphurea'],
        ['Philippine Pygmy Woodpecker', 'Yungipicus maculatus'] ]

# %%
df_species = pd.DataFrame(data,columns =['english name',
                                         'scientific name'])
gen = []
sp = []

# %%
for name in df_species['scientific name']:
    gen.append(name.rpartition(' ')[0])
    sp.append(name.rpartition(' ')[2])

# %%
df_query = pd.DataFrame()
df_query['param1'] = gen
df_query['param2'] = sp
# query_param = urllib.parse.quote('type:"alarm call"')
# df_query['param3'] = query_param
df_query['param3'] ='area:asia'
# df_query['param5'] ='len:"5-120"'
# df_query['param5'] ='q:">C"'

# %%
# Get recordings metadata corresponding to the query
df_dataset= util.xc_multi_query(df_query,
                                 format_time = False,
                                 format_date = False,
                                 verbose=True)
# Out:
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Passer%20montanus%20area:asia&page=1
# Found 1 pages in total.
# Saved metadata for 233 files
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Geopelia%20striata%20area:asia&page=1
# Found 1 pages in total.
# Saved metadata for 116 files
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Gerygone%20sulphurea%20area:asia&page=1
# Found 1 pages in total.
# Saved metadata for 74 files
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Yungipicus%20maculatus%20area:asia&page=1
# Found 1 pages in total.
# Saved metadata for 26 files

# %%
df_dataset = util.xc_selection(df_dataset,
                               max_nb_files=25,
                               max_length='01:00',
                               min_length='00:10',
                               # min_quality='B',
                               verbose = True )
# Out:
# Passer montanus
#     ... request 25 files of quality A
#     --> found 25 files of quality A and 00:10<length<01:00
#     total files : 25
# -----------------------------------------
# Geopelia striata
#     ... request 25 files of quality A
#     --> found 12 files of quality A and 00:10<length<01:00
#     ... request 13 files of quality B
#     --> found 13 files of quality B and 00:10<length<01:00
#     total files : 25
# -----------------------------------------
# Gerygone sulphurea
#     ... request 25 files of quality A
#     --> found  2 files of quality A and 00:10<length<01:00
#     ... request 23 files of quality B
#     --> found 23 files of quality B and 00:10<length<01:00
#     total files : 25
# -----------------------------------------
# Yungipicus maculatus
#     ... request 25 files of quality A
#     --> found  0 files of quality A and 00:10<length<01:00
#     ... request 25 files of quality B
#     --> found  9 files of quality B and 00:10<length<01:00
#     total files :  9
# -----------------------------------------

# %%
util.xc_download(df_dataset,
                 rootdir = XC_ROOTDIR,
                 dataset_name= XC_DIR,
                 overwrite=False,
                 save_csv= True,
                 verbose = True)
# Out:
# A total of 84 files will be downloaded
# Creating subdirectory dataset\data_sets\Passer montanus_Eurasian Tree Sparrow for downloaded files...
# Saving file  1 / 84 : https://xeno-canto.org/442223/download
# Saving file  2 / 84 : https://xeno-canto.org/899193/download
# Saving file  3 / 84 : https://xeno-canto.org/710681/download
# Saving file  4 / 84 : https://xeno-canto.org/799941/download
# Saving file  5 / 84 : https://xeno-canto.org/589446/download
# Saving file  6 / 84 : https://xeno-canto.org/657799/download
# Saving file  7 / 84 : https://xeno-canto.org/899208/download
# Saving file  8 / 84 : https://xeno-canto.org/398708/download
# Saving file  9 / 84 : https://xeno-canto.org/162523/download
# Saving file  10 / 84 : https://xeno-canto.org/35776/download
# C:\Users\Caleb Perez\AppData\Local\Programs\Python\Python312\Lib\site-packages\maad\util\xeno_canto.py:462: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.conc
# 899193                                      Ili, Xinjiang  43.8842   81.2507
# 710681                        Tianlin Community, Shanghai  31.1741  121.4214
# 799941  Kong Krid Resort, Tambon Muang Yai, Amphoe Wia...  20.1114  100.5161
# 589446                  Luang Prabang town, Luang Prabang  19.8891  102.1389
# ...                                                   ...      ...       ...
# 606188  New Bataan (near  Maragusan), Compostela Valle...   7.4255  126.1660
# 211957        Milan Falls, Eastern Samar, Eastern Visayas  11.8199  125.2926
# 68130                                 Negros; Mt. Canlaon  10.4000  123.1000
# 606190        New Bataan, Compostela Valley, Davao Region   7.4554  126.1735
# 617344  Near waterfall trail, Samar National Park, Eas...  11.8265  125.2890
#
#         ... bird-seen animal-seen playback-used temp regnr auto  \
# id      ...
# 442223  ...       yes         yes            no              no
# 899193  ...       yes         yes            no              no
# 710681  ...        no          no            no              no
# 799941  ...       yes         yes            no              no
# 589446  ...        no          no            no              no
# ...     ...       ...         ...           ...  ...   ...  ...
# 606188  ...   unknown     unknown            no              no
# 211957  ...       yes         yes            no              no
# 68130   ...   unknown     unknown       unknown              no
# 606190  ...   unknown     unknown            no              no
# 617344  ...        no          no            no              no
#
#                          dvc                   mic    smp  \
# id
# 442223                                              48000
# 899193     Sound Devices 722  Telinga Twin Science  48000
# 710681                                              48000
# 799941  Tascam DR-100 MK III  Sennheiser ME66 & K6  48000
# 589446                                              44100
# ...                      ...                   ...    ...
# 606188                                              44100
# 211957                                              44100
# 68130                                               48000
# 606190                                              44100
# 617344                                              44100
#
#                                              fullfilename
# id
# 442223  dataset\data_sets\Passer montanus_Eurasian Tre...
# 899193  dataset\data_sets\Passer montanus_Eurasian Tre...
# 710681  dataset\data_sets\Passer montanus_Eurasian Tre...
# 799941  dataset\data_sets\Passer montanus_Eurasian Tre...
# 589446  dataset\data_sets\Passer montanus_Eurasian Tre...
# ...                                                   ...
# 606188  dataset\data_sets\Yungipicus maculatus_Philipp...
# 211957  dataset\data_sets\Yungipicus maculatus_Philipp...
# 68130   dataset\data_sets\Yungipicus maculatus_Philipp...
# 606190  dataset\data_sets\Yungipicus maculatus_Philipp...
# 617344  dataset\data_sets\Yungipicus maculatus_Philipp...
#
# [84 rows x 38 columns]

# %%
filelist = grab_audio(XC_ROOTDIR+XC_DIR)

# %%
df = pd.DataFrame()

# %%
for file in filelist:
    df = df.append({'fullfilename': file,
                    'filename': Path(file).parts[-1][:-4],
                    'species': Path(file).parts[-2]},
                   ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12816\3624869857.py in ?()
#       1 for file in filelist:
# ----> 2     df = df.append({'fullfilename': file,
#       3                     'filename': Path(file).parts[-1][:-4],
#       4                     'species': Path(file).parts[-2]},
#       5                    ignore_index=True)
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
print('=====================================================')
print('number of files : %2.0f' % len(df))
print('number of species : %2.0f' % len(df.species.unique()))
print('=====================================================')

# %%
df.head()
# newdf = pd.read_csv('./dataset/data_sets/Passer montanus_Eurasian Tree Sparrow/metadata.csv')
# newdf.head()
